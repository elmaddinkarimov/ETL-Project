# %%
import pandas as pd
import json
from pandas.io.json import json_normalize
cat=[]

# %%
csvfile="youtube-new/CAvideos.csv"
df_ca=pd.read_csv(csvfile)
df_ca.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           23  2017-11-13T17:00:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# ...

# %%
df_ca.describe()
# Out:
#         category_id         views         likes      dislikes  comment_count
# count  40881.000000  4.088100e+04  4.088100e+04  4.088100e+04   4.088100e+04
# mean      20.795553  1.147036e+06  3.958269e+04  2.009195e+03   5.042975e+03
# std        6.775054  3.390913e+06  1.326895e+05  1.900837e+04   2.157902e+04
# min        1.000000  7.330000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       20.000000  1.439020e+05  2.191000e+03  9.900000e+01   4.170000e+02
# 50%       24.000000  3.712040e+05  8.780000e+03  3.030000e+02   1.301000e+03
# 75%       24.000000  9.633020e+05  2.871700e+04  9.500000e+02   3.713000e+03
# max       43.000000  1.378431e+08  5.053338e+06  1.602383e+06   1.114800e+06

# %%
df_ca.count()
# Out:
# video_id                  40881
# trending_date             40881
# title                     40881
# channel_title             40881
# category_id               40881
# publish_time              40881
# tags                      40881
# views                     40881
# likes                     40881
# dislikes                  40881
# comment_count             40881
# thumbnail_link            40881
# comments_disabled         40881
# ratings_disabled          40881
# video_error_or_removed    40881
# description               39585
# dtype: int64

# %%
json_file="youtube-new/CA_category_id.json"
type(json_file)
# Out:
# str

# %%
df_ca_json=pd.read_json(json_file)
df_ca_json.head()
# Out:
#                                 kind  \
# 0  youtube#videoCategoryListResponse
# 1  youtube#videoCategoryListResponse
# 2  youtube#videoCategoryListResponse
# 3  youtube#videoCategoryListResponse
# 4  youtube#videoCategoryListResponse
#
#                                                 etag  \
# 0  "ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2...
# 1  "ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2...
# 2  "ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2...
# 3  "ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2...
# 4  "ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2...
#
#                                                items
# 0  {'kind': 'youtube#videoCategory', 'etag': '"ld...
# 1  {'kind': 'youtube#videoCategory', 'etag': '"ld...
# 2  {'kind': 'youtube#videoCategory', 'etag': '"ld...
# 3  {'kind': 'youtube#videoCategory', 'etag': '"ld...
# 4  {'kind': 'youtube#videoCategory', 'etag': '"ld...

# %%
list_countries=["youtube-new/CA_category_id.json","youtube-new/US_category_id.json","youtube-new/GB_category_id.json"]

# %%
for country in list_countries:
    json_data=json.load(open(country, 'r'))
    for data in json_data['items']:
        cat.append([data['id'],country[12:14],data['snippet']['title']])
            
cat
# Out:
# [['1', 'CA', 'Film & Animation'],
#  ['2', 'CA', 'Autos & Vehicles'],
#  ['10', 'CA', 'Music'],
#  ['15', 'CA', 'Pets & Animals'],
#  ['17', 'CA', 'Sports'],
#  ['18', 'CA', 'Short Movies'],
#  ['19', 'CA', 'Travel & Events'],
#  ['20', 'CA', 'Gaming'],
#  ['21', 'CA', 'Videoblogging'],
#  ['22', 'CA', 'People & Blogs'],
#  ['23', 'CA', 'Comedy'],
#  ['24', 'CA', 'Entertainment'],
#  ['25', 'CA', 'News & Politics'],
#  ['26', 'CA', 'Howto & Style'],
#  ['27', 'CA', 'Education'],
#  ['28', 'CA', 'Science & Technology'],
#  ['30', 'CA', 'Movies'],
#  ['31', 'CA', 'Anime/Animation'],
#  ['32', 'CA', 'Action/Adventure'],
#  ['33', 'CA', 'Classics'],
#  ['34', 'CA', 'Comedy'],
#  ['35', 'CA', 'Documentary'],
#  ['36', 'CA', 'Drama'],
#  ['37', 'CA', 'Family'],
#  ['38', 'CA', 'Foreign'],
#  ['39', 'CA', 'Horror'],
#  ['40', 'CA', 'Sci-Fi/Fantasy'],
#  ['41', 'CA', 'Thriller'],
#  ['42', 'CA', 'Shorts'],
#  ['43', 'CA', 'Shows'],
#  ['44', 'CA', 'Trailers'],
# ...

# %%
category_df=pd.DataFrame(cat,columns=['Category_id','Country','Category_name'])
category_df.head(200)
# Out:
#    Category_id Country         Category_name
# 0            1      CA      Film & Animation
# 1            2      CA      Autos & Vehicles
# 2           10      CA                 Music
# 3           15      CA        Pets & Animals
# 4           17      CA                Sports
# 5           18      CA          Short Movies
# 6           19      CA       Travel & Events
# 7           20      CA                Gaming
# 8           21      CA         Videoblogging
# 9           22      CA        People & Blogs
# 10          23      CA                Comedy
# 11          24      CA         Entertainment
# 12          25      CA       News & Politics
# 13          26      CA         Howto & Style
# 14          27      CA             Education
# 15          28      CA  Science & Technology
# 16          30      CA                Movies
# 17          31      CA       Anime/Animation
# 18          32      CA      Action/Adventure
# 19          33      CA              Classics
# ...
