# %%
import pandas as pd
import json
from pandas.io.json import json_normalize
cat=[]

# %%
json_file="resources/CA_category_id.json"
type(json_file)
# Out:
# str

# %%
df_ca_json=pd.read_json(json_file)
df_ca_json.head()
# Out:
#                                 kind  \
# 0  youtube#videoCategoryListResponse
# 1  youtube#videoCategoryListResponse
# 2  youtube#videoCategoryListResponse
# 3  youtube#videoCategoryListResponse
# 4  youtube#videoCategoryListResponse
#
#                                                 etag  \
# 0  "ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2...
# 1  "ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2...
# 2  "ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2...
# 3  "ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2...
# 4  "ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2...
#
#                                                items
# 0  {'kind': 'youtube#videoCategory', 'etag': '"ld...
# 1  {'kind': 'youtube#videoCategory', 'etag': '"ld...
# 2  {'kind': 'youtube#videoCategory', 'etag': '"ld...
# 3  {'kind': 'youtube#videoCategory', 'etag': '"ld...
# 4  {'kind': 'youtube#videoCategory', 'etag': '"ld...

# %%
list_countries=["resources/CA_category_id.json","resources/US_category_id.json","resources/GB_category_id.json"]

# %%
for country in list_countries:
    json_data=json.load(open(country, 'r'))
    for data in json_data['items']:
        cat.append([data['id'],country[10:12],data['snippet']['title']])
            
cat
# Out:
# [['1', '_c', 'Film & Animation'],
#  ['2', '_c', 'Autos & Vehicles'],
#  ['10', '_c', 'Music'],
#  ['15', '_c', 'Pets & Animals'],
#  ['17', '_c', 'Sports'],
#  ['18', '_c', 'Short Movies'],
#  ['19', '_c', 'Travel & Events'],
#  ['20', '_c', 'Gaming'],
#  ['21', '_c', 'Videoblogging'],
#  ['22', '_c', 'People & Blogs'],
#  ['23', '_c', 'Comedy'],
#  ['24', '_c', 'Entertainment'],
#  ['25', '_c', 'News & Politics'],
#  ['26', '_c', 'Howto & Style'],
#  ['27', '_c', 'Education'],
#  ['28', '_c', 'Science & Technology'],
#  ['30', '_c', 'Movies'],
#  ['31', '_c', 'Anime/Animation'],
#  ['32', '_c', 'Action/Adventure'],
#  ['33', '_c', 'Classics'],
#  ['34', '_c', 'Comedy'],
#  ['35', '_c', 'Documentary'],
#  ['36', '_c', 'Drama'],
#  ['37', '_c', 'Family'],
#  ['38', '_c', 'Foreign'],
#  ['39', '_c', 'Horror'],
#  ['40', '_c', 'Sci-Fi/Fantasy'],
#  ['41', '_c', 'Thriller'],
#  ['42', '_c', 'Shorts'],
#  ['43', '_c', 'Shows'],
#  ['44', '_c', 'Trailers'],
#  ['1', '_c', 'Film & Animation'],
#  ['2', '_c', 'Autos & Vehicles'],
#  ['10', '_c', 'Music'],
#  ['15', '_c', 'Pets & Animals'],
#  ['17', '_c', 'Sports'],
#  ['18', '_c', 'Short Movies'],
#  ['19', '_c', 'Travel & Events'],
#  ['20', '_c', 'Gaming'],
#  ['21', '_c', 'Videoblogging'],
#  ['22', '_c', 'People & Blogs'],
#  ['23', '_c', 'Comedy'],
#  ['24', '_c', 'Entertainment'],
#  ['25', '_c', 'News & Politics'],
#  ['26', '_c', 'Howto & Style'],
#  ['27', '_c', 'Education'],
#  ['28', '_c', 'Science & Technology'],
#  ['29', '_c', 'Nonprofits & Activism'],
#  ['30', '_c', 'Movies'],
#  ['31', '_c', 'Anime/Animation'],
#  ['32', '_c', 'Action/Adventure'],
#  ['33', '_c', 'Classics'],
#  ['34', '_c', 'Comedy'],
#  ['35', '_c', 'Documentary'],
#  ['36', '_c', 'Drama'],
#  ['37', '_c', 'Family'],
#  ['38', '_c', 'Foreign'],
#  ['39', '_c', 'Horror'],
#  ['40', '_c', 'Sci-Fi/Fantasy'],
#  ['41', '_c', 'Thriller'],
#  ['42', '_c', 'Shorts'],
#  ['43', '_c', 'Shows'],
#  ['44', '_c', 'Trailers'],
#  ['1', '_c', 'Film & Animation'],
#  ['2', '_c', 'Autos & Vehicles'],
#  ['10', '_c', 'Music'],
#  ['15', '_c', 'Pets & Animals'],
#  ['17', '_c', 'Sports'],
#  ['18', '_c', 'Short Movies'],
#  ['19', '_c', 'Travel & Events'],
#  ['20', '_c', 'Gaming'],
#  ['21', '_c', 'Videoblogging'],
#  ['22', '_c', 'People & Blogs'],
#  ['23', '_c', 'Comedy'],
#  ['24', '_c', 'Entertainment'],
#  ['25', '_c', 'News & Politics'],
#  ['26', '_c', 'Howto & Style'],
#  ['27', '_c', 'Education'],
#  ['28', '_c', 'Science & Technology'],
#  ['30', '_c', 'Movies'],
#  ['31', '_c', 'Anime/Animation'],
#  ['32', '_c', 'Action/Adventure'],
#  ['33', '_c', 'Classics'],
#  ['34', '_c', 'Comedy'],
#  ['35', '_c', 'Documentary'],
#  ['36', '_c', 'Drama'],
#  ['37', '_c', 'Family'],
#  ['38', '_c', 'Foreign'],
#  ['39', '_c', 'Horror'],
#  ['40', '_c', 'Sci-Fi/Fantasy'],
#  ['41', '_c', 'Thriller'],
#  ['42', '_c', 'Shorts'],
#  ['43', '_c', 'Shows'],
#  ['44', '_c', 'Trailers'],
#  ['1', 'CA', 'Film & Animation'],
#  ['2', 'CA', 'Autos & Vehicles'],
#  ['10', 'CA', 'Music'],
#  ['15', 'CA', 'Pets & Animals'],
#  ['17', 'CA', 'Sports'],
#  ['18', 'CA', 'Short Movies'],
#  ['19', 'CA', 'Travel & Events'],
#  ['20', 'CA', 'Gaming'],
#  ['21', 'CA', 'Videoblogging'],
#  ['22', 'CA', 'People & Blogs'],
#  ['23', 'CA', 'Comedy'],
#  ['24', 'CA', 'Entertainment'],
#  ['25', 'CA', 'News & Politics'],
#  ['26', 'CA', 'Howto & Style'],
#  ['27', 'CA', 'Education'],
#  ['28', 'CA', 'Science & Technology'],
#  ['30', 'CA', 'Movies'],
#  ['31', 'CA', 'Anime/Animation'],
#  ['32', 'CA', 'Action/Adventure'],
#  ['33', 'CA', 'Classics'],
#  ['34', 'CA', 'Comedy'],
#  ['35', 'CA', 'Documentary'],
#  ['36', 'CA', 'Drama'],
#  ['37', 'CA', 'Family'],
#  ['38', 'CA', 'Foreign'],
#  ['39', 'CA', 'Horror'],
#  ['40', 'CA', 'Sci-Fi/Fantasy'],
#  ['41', 'CA', 'Thriller'],
#  ['42', 'CA', 'Shorts'],
#  ['43', 'CA', 'Shows'],
#  ['44', 'CA', 'Trailers'],
#  ['1', 'US', 'Film & Animation'],
#  ['2', 'US', 'Autos & Vehicles'],
#  ['10', 'US', 'Music'],
#  ['15', 'US', 'Pets & Animals'],
#  ['17', 'US', 'Sports'],
#  ['18', 'US', 'Short Movies'],
#  ['19', 'US', 'Travel & Events'],
#  ['20', 'US', 'Gaming'],
#  ['21', 'US', 'Videoblogging'],
#  ['22', 'US', 'People & Blogs'],
#  ['23', 'US', 'Comedy'],
#  ['24', 'US', 'Entertainment'],
#  ['25', 'US', 'News & Politics'],
#  ['26', 'US', 'Howto & Style'],
#  ['27', 'US', 'Education'],
#  ['28', 'US', 'Science & Technology'],
#  ['29', 'US', 'Nonprofits & Activism'],
#  ['30', 'US', 'Movies'],
#  ['31', 'US', 'Anime/Animation'],
#  ['32', 'US', 'Action/Adventure'],
#  ['33', 'US', 'Classics'],
#  ['34', 'US', 'Comedy'],
#  ['35', 'US', 'Documentary'],
#  ['36', 'US', 'Drama'],
#  ['37', 'US', 'Family'],
#  ['38', 'US', 'Foreign'],
#  ['39', 'US', 'Horror'],
#  ['40', 'US', 'Sci-Fi/Fantasy'],
#  ['41', 'US', 'Thriller'],
#  ['42', 'US', 'Shorts'],
#  ['43', 'US', 'Shows'],
#  ['44', 'US', 'Trailers'],
#  ['1', 'GB', 'Film & Animation'],
#  ['2', 'GB', 'Autos & Vehicles'],
#  ['10', 'GB', 'Music'],
#  ['15', 'GB', 'Pets & Animals'],
#  ['17', 'GB', 'Sports'],
#  ['18', 'GB', 'Short Movies'],
#  ['19', 'GB', 'Travel & Events'],
#  ['20', 'GB', 'Gaming'],
#  ['21', 'GB', 'Videoblogging'],
#  ['22', 'GB', 'People & Blogs'],
#  ['23', 'GB', 'Comedy'],
#  ['24', 'GB', 'Entertainment'],
#  ['25', 'GB', 'News & Politics'],
#  ['26', 'GB', 'Howto & Style'],
#  ['27', 'GB', 'Education'],
#  ['28', 'GB', 'Science & Technology'],
#  ['30', 'GB', 'Movies'],
#  ['31', 'GB', 'Anime/Animation'],
#  ['32', 'GB', 'Action/Adventure'],
#  ['33', 'GB', 'Classics'],
#  ['34', 'GB', 'Comedy'],
#  ['35', 'GB', 'Documentary'],
#  ['36', 'GB', 'Drama'],
#  ['37', 'GB', 'Family'],
#  ['38', 'GB', 'Foreign'],
#  ['39', 'GB', 'Horror'],
#  ['40', 'GB', 'Sci-Fi/Fantasy'],
#  ['41', 'GB', 'Thriller'],
#  ['42', 'GB', 'Shorts'],
#  ['43', 'GB', 'Shows'],
#  ['44', 'GB', 'Trailers'],
#  ['1', 'CA', 'Film & Animation'],
#  ['2', 'CA', 'Autos & Vehicles'],
#  ['10', 'CA', 'Music'],
#  ['15', 'CA', 'Pets & Animals'],
#  ['17', 'CA', 'Sports'],
#  ['18', 'CA', 'Short Movies'],
#  ['19', 'CA', 'Travel & Events'],
#  ['20', 'CA', 'Gaming'],
#  ['21', 'CA', 'Videoblogging'],
#  ['22', 'CA', 'People & Blogs'],
#  ['23', 'CA', 'Comedy'],
#  ['24', 'CA', 'Entertainment'],
#  ['25', 'CA', 'News & Politics'],
#  ['26', 'CA', 'Howto & Style'],
#  ['27', 'CA', 'Education'],
#  ['28', 'CA', 'Science & Technology'],
#  ['30', 'CA', 'Movies'],
#  ['31', 'CA', 'Anime/Animation'],
#  ['32', 'CA', 'Action/Adventure'],
#  ['33', 'CA', 'Classics'],
#  ['34', 'CA', 'Comedy'],
#  ['35', 'CA', 'Documentary'],
#  ['36', 'CA', 'Drama'],
#  ['37', 'CA', 'Family'],
#  ['38', 'CA', 'Foreign'],
#  ['39', 'CA', 'Horror'],
#  ['40', 'CA', 'Sci-Fi/Fantasy'],
#  ['41', 'CA', 'Thriller'],
#  ['42', 'CA', 'Shorts'],
#  ['43', 'CA', 'Shows'],
#  ['44', 'CA', 'Trailers'],
#  ['1', 'US', 'Film & Animation'],
#  ['2', 'US', 'Autos & Vehicles'],
#  ['10', 'US', 'Music'],
#  ['15', 'US', 'Pets & Animals'],
#  ['17', 'US', 'Sports'],
#  ['18', 'US', 'Short Movies'],
#  ['19', 'US', 'Travel & Events'],
#  ['20', 'US', 'Gaming'],
#  ['21', 'US', 'Videoblogging'],
#  ['22', 'US', 'People & Blogs'],
#  ['23', 'US', 'Comedy'],
#  ['24', 'US', 'Entertainment'],
#  ['25', 'US', 'News & Politics'],
#  ['26', 'US', 'Howto & Style'],
#  ['27', 'US', 'Education'],
#  ['28', 'US', 'Science & Technology'],
#  ['29', 'US', 'Nonprofits & Activism'],
#  ['30', 'US', 'Movies'],
#  ['31', 'US', 'Anime/Animation'],
#  ['32', 'US', 'Action/Adventure'],
#  ['33', 'US', 'Classics'],
#  ['34', 'US', 'Comedy'],
#  ['35', 'US', 'Documentary'],
#  ['36', 'US', 'Drama'],
#  ['37', 'US', 'Family'],
#  ['38', 'US', 'Foreign'],
#  ['39', 'US', 'Horror'],
#  ['40', 'US', 'Sci-Fi/Fantasy'],
#  ['41', 'US', 'Thriller'],
#  ['42', 'US', 'Shorts'],
#  ['43', 'US', 'Shows'],
#  ['44', 'US', 'Trailers'],
#  ['1', 'GB', 'Film & Animation'],
#  ['2', 'GB', 'Autos & Vehicles'],
#  ['10', 'GB', 'Music'],
#  ['15', 'GB', 'Pets & Animals'],
#  ['17', 'GB', 'Sports'],
#  ['18', 'GB', 'Short Movies'],
#  ['19', 'GB', 'Travel & Events'],
#  ['20', 'GB', 'Gaming'],
#  ['21', 'GB', 'Videoblogging'],
#  ['22', 'GB', 'People & Blogs'],
#  ['23', 'GB', 'Comedy'],
#  ['24', 'GB', 'Entertainment'],
#  ['25', 'GB', 'News & Politics'],
#  ['26', 'GB', 'Howto & Style'],
#  ['27', 'GB', 'Education'],
#  ['28', 'GB', 'Science & Technology'],
#  ['30', 'GB', 'Movies'],
#  ['31', 'GB', 'Anime/Animation'],
#  ['32', 'GB', 'Action/Adventure'],
#  ['33', 'GB', 'Classics'],
#  ['34', 'GB', 'Comedy'],
#  ['35', 'GB', 'Documentary'],
#  ['36', 'GB', 'Drama'],
#  ['37', 'GB', 'Family'],
#  ['38', 'GB', 'Foreign'],
#  ['39', 'GB', 'Horror'],
#  ['40', 'GB', 'Sci-Fi/Fantasy'],
#  ['41', 'GB', 'Thriller'],
#  ['42', 'GB', 'Shorts'],
#  ['43', 'GB', 'Shows'],
#  ['44', 'GB', 'Trailers'],
#  ['1', 'CA', 'Film & Animation'],
#  ['2', 'CA', 'Autos & Vehicles'],
#  ['10', 'CA', 'Music'],
#  ['15', 'CA', 'Pets & Animals'],
#  ['17', 'CA', 'Sports'],
#  ['18', 'CA', 'Short Movies'],
#  ['19', 'CA', 'Travel & Events'],
#  ['20', 'CA', 'Gaming'],
#  ['21', 'CA', 'Videoblogging'],
#  ['22', 'CA', 'People & Blogs'],
#  ['23', 'CA', 'Comedy'],
#  ['24', 'CA', 'Entertainment'],
#  ['25', 'CA', 'News & Politics'],
#  ['26', 'CA', 'Howto & Style'],
#  ['27', 'CA', 'Education'],
#  ['28', 'CA', 'Science & Technology'],
#  ['30', 'CA', 'Movies'],
#  ['31', 'CA', 'Anime/Animation'],
#  ['32', 'CA', 'Action/Adventure'],
#  ['33', 'CA', 'Classics'],
#  ['34', 'CA', 'Comedy'],
#  ['35', 'CA', 'Documentary'],
#  ['36', 'CA', 'Drama'],
#  ['37', 'CA', 'Family'],
#  ['38', 'CA', 'Foreign'],
#  ['39', 'CA', 'Horror'],
#  ['40', 'CA', 'Sci-Fi/Fantasy'],
#  ['41', 'CA', 'Thriller'],
#  ['42', 'CA', 'Shorts'],
#  ['43', 'CA', 'Shows'],
#  ['44', 'CA', 'Trailers'],
#  ['1', 'US', 'Film & Animation'],
#  ['2', 'US', 'Autos & Vehicles'],
#  ['10', 'US', 'Music'],
#  ['15', 'US', 'Pets & Animals'],
#  ['17', 'US', 'Sports'],
#  ['18', 'US', 'Short Movies'],
#  ['19', 'US', 'Travel & Events'],
#  ['20', 'US', 'Gaming'],
#  ['21', 'US', 'Videoblogging'],
#  ['22', 'US', 'People & Blogs'],
#  ['23', 'US', 'Comedy'],
#  ['24', 'US', 'Entertainment'],
#  ['25', 'US', 'News & Politics'],
#  ['26', 'US', 'Howto & Style'],
#  ['27', 'US', 'Education'],
#  ['28', 'US', 'Science & Technology'],
#  ['29', 'US', 'Nonprofits & Activism'],
#  ['30', 'US', 'Movies'],
#  ['31', 'US', 'Anime/Animation'],
#  ['32', 'US', 'Action/Adventure'],
#  ['33', 'US', 'Classics'],
#  ['34', 'US', 'Comedy'],
#  ['35', 'US', 'Documentary'],
#  ['36', 'US', 'Drama'],
#  ['37', 'US', 'Family'],
#  ['38', 'US', 'Foreign'],
#  ['39', 'US', 'Horror'],
#  ['40', 'US', 'Sci-Fi/Fantasy'],
#  ['41', 'US', 'Thriller'],
#  ['42', 'US', 'Shorts'],
#  ['43', 'US', 'Shows'],
#  ['44', 'US', 'Trailers'],
#  ['1', 'GB', 'Film & Animation'],
#  ['2', 'GB', 'Autos & Vehicles'],
#  ['10', 'GB', 'Music'],
#  ['15', 'GB', 'Pets & Animals'],
#  ['17', 'GB', 'Sports'],
#  ['18', 'GB', 'Short Movies'],
#  ['19', 'GB', 'Travel & Events'],
#  ['20', 'GB', 'Gaming'],
#  ['21', 'GB', 'Videoblogging'],
#  ['22', 'GB', 'People & Blogs'],
#  ['23', 'GB', 'Comedy'],
#  ['24', 'GB', 'Entertainment'],
#  ['25', 'GB', 'News & Politics'],
#  ['26', 'GB', 'Howto & Style'],
#  ['27', 'GB', 'Education'],
#  ['28', 'GB', 'Science & Technology'],
#  ['30', 'GB', 'Movies'],
#  ['31', 'GB', 'Anime/Animation'],
#  ['32', 'GB', 'Action/Adventure'],
#  ['33', 'GB', 'Classics'],
#  ['34', 'GB', 'Comedy'],
#  ['35', 'GB', 'Documentary'],
#  ['36', 'GB', 'Drama'],
#  ['37', 'GB', 'Family'],
#  ['38', 'GB', 'Foreign'],
#  ['39', 'GB', 'Horror'],
#  ['40', 'GB', 'Sci-Fi/Fantasy'],
#  ['41', 'GB', 'Thriller'],
#  ['42', 'GB', 'Shorts'],
#  ['43', 'GB', 'Shows'],
#  ['44', 'GB', 'Trailers'],
#  ['1', 'Film & Animation'],
#  ['2', 'Autos & Vehicles'],
#  ['10', 'Music'],
#  ['15', 'Pets & Animals'],
#  ['17', 'Sports'],
#  ['18', 'Short Movies'],
#  ['19', 'Travel & Events'],
#  ['20', 'Gaming'],
#  ['21', 'Videoblogging'],
#  ['22', 'People & Blogs'],
#  ['23', 'Comedy'],
#  ['24', 'Entertainment'],
#  ['25', 'News & Politics'],
#  ['26', 'Howto & Style'],
#  ['27', 'Education'],
#  ['28', 'Science & Technology'],
#  ['30', 'Movies'],
#  ['31', 'Anime/Animation'],
#  ['32', 'Action/Adventure'],
#  ['33', 'Classics'],
#  ['34', 'Comedy'],
#  ['35', 'Documentary'],
#  ['36', 'Drama'],
#  ['37', 'Family'],
#  ['38', 'Foreign'],
#  ['39', 'Horror'],
#  ['40', 'Sci-Fi/Fantasy'],
#  ['41', 'Thriller'],
#  ['42', 'Shorts'],
#  ['43', 'Shows'],
#  ['44', 'Trailers'],
#  ['1', 'Film & Animation'],
#  ['2', 'Autos & Vehicles'],
#  ['10', 'Music'],
#  ['15', 'Pets & Animals'],
#  ['17', 'Sports'],
#  ['18', 'Short Movies'],
#  ['19', 'Travel & Events'],
#  ['20', 'Gaming'],
#  ['21', 'Videoblogging'],
#  ['22', 'People & Blogs'],
#  ['23', 'Comedy'],
#  ['24', 'Entertainment'],
#  ['25', 'News & Politics'],
#  ['26', 'Howto & Style'],
#  ['27', 'Education'],
#  ['28', 'Science & Technology'],
#  ['29', 'Nonprofits & Activism'],
#  ['30', 'Movies'],
#  ['31', 'Anime/Animation'],
#  ['32', 'Action/Adventure'],
#  ['33', 'Classics'],
#  ['34', 'Comedy'],
#  ['35', 'Documentary'],
#  ['36', 'Drama'],
#  ['37', 'Family'],
#  ['38', 'Foreign'],
#  ['39', 'Horror'],
#  ['40', 'Sci-Fi/Fantasy'],
#  ['41', 'Thriller'],
#  ['42', 'Shorts'],
#  ['43', 'Shows'],
#  ['44', 'Trailers'],
#  ['1', 'Film & Animation'],
#  ['2', 'Autos & Vehicles'],
#  ['10', 'Music'],
#  ['15', 'Pets & Animals'],
#  ['17', 'Sports'],
#  ['18', 'Short Movies'],
#  ['19', 'Travel & Events'],
#  ['20', 'Gaming'],
#  ['21', 'Videoblogging'],
#  ['22', 'People & Blogs'],
#  ['23', 'Comedy'],
#  ['24', 'Entertainment'],
#  ['25', 'News & Politics'],
#  ['26', 'Howto & Style'],
#  ['27', 'Education'],
#  ['28', 'Science & Technology'],
#  ['30', 'Movies'],
#  ['31', 'Anime/Animation'],
#  ['32', 'Action/Adventure'],
#  ['33', 'Classics'],
#  ['34', 'Comedy'],
#  ['35', 'Documentary'],
#  ['36', 'Drama'],
#  ['37', 'Family'],
#  ['38', 'Foreign'],
#  ['39', 'Horror'],
#  ['40', 'Sci-Fi/Fantasy'],
#  ['41', 'Thriller'],
#  ['42', 'Shorts'],
#  ['43', 'Shows'],
#  ['44', 'Trailers'],
#  ['1', 'CA', 'Film & Animation'],
#  ['2', 'CA', 'Autos & Vehicles'],
#  ['10', 'CA', 'Music'],
#  ['15', 'CA', 'Pets & Animals'],
#  ['17', 'CA', 'Sports'],
#  ['18', 'CA', 'Short Movies'],
#  ['19', 'CA', 'Travel & Events'],
#  ['20', 'CA', 'Gaming'],
#  ['21', 'CA', 'Videoblogging'],
#  ['22', 'CA', 'People & Blogs'],
#  ['23', 'CA', 'Comedy'],
#  ['24', 'CA', 'Entertainment'],
#  ['25', 'CA', 'News & Politics'],
#  ['26', 'CA', 'Howto & Style'],
#  ['27', 'CA', 'Education'],
#  ['28', 'CA', 'Science & Technology'],
#  ['30', 'CA', 'Movies'],
#  ['31', 'CA', 'Anime/Animation'],
#  ['32', 'CA', 'Action/Adventure'],
#  ['33', 'CA', 'Classics'],
#  ['34', 'CA', 'Comedy'],
#  ['35', 'CA', 'Documentary'],
#  ['36', 'CA', 'Drama'],
#  ['37', 'CA', 'Family'],
#  ['38', 'CA', 'Foreign'],
#  ['39', 'CA', 'Horror'],
#  ['40', 'CA', 'Sci-Fi/Fantasy'],
#  ['41', 'CA', 'Thriller'],
#  ['42', 'CA', 'Shorts'],
#  ['43', 'CA', 'Shows'],
#  ['44', 'CA', 'Trailers'],
#  ['1', 'US', 'Film & Animation'],
#  ['2', 'US', 'Autos & Vehicles'],
#  ['10', 'US', 'Music'],
#  ['15', 'US', 'Pets & Animals'],
#  ['17', 'US', 'Sports'],
#  ['18', 'US', 'Short Movies'],
#  ['19', 'US', 'Travel & Events'],
#  ['20', 'US', 'Gaming'],
#  ['21', 'US', 'Videoblogging'],
#  ['22', 'US', 'People & Blogs'],
#  ['23', 'US', 'Comedy'],
#  ['24', 'US', 'Entertainment'],
#  ['25', 'US', 'News & Politics'],
#  ['26', 'US', 'Howto & Style'],
#  ['27', 'US', 'Education'],
#  ['28', 'US', 'Science & Technology'],
#  ['29', 'US', 'Nonprofits & Activism'],
#  ['30', 'US', 'Movies'],
#  ['31', 'US', 'Anime/Animation'],
#  ['32', 'US', 'Action/Adventure'],
#  ['33', 'US', 'Classics'],
#  ['34', 'US', 'Comedy'],
#  ['35', 'US', 'Documentary'],
#  ['36', 'US', 'Drama'],
#  ['37', 'US', 'Family'],
#  ['38', 'US', 'Foreign'],
#  ['39', 'US', 'Horror'],
#  ['40', 'US', 'Sci-Fi/Fantasy'],
#  ['41', 'US', 'Thriller'],
#  ['42', 'US', 'Shorts'],
#  ['43', 'US', 'Shows'],
#  ['44', 'US', 'Trailers'],
#  ['1', 'GB', 'Film & Animation'],
#  ['2', 'GB', 'Autos & Vehicles'],
#  ['10', 'GB', 'Music'],
#  ['15', 'GB', 'Pets & Animals'],
#  ['17', 'GB', 'Sports'],
#  ['18', 'GB', 'Short Movies'],
#  ['19', 'GB', 'Travel & Events'],
#  ['20', 'GB', 'Gaming'],
#  ['21', 'GB', 'Videoblogging'],
#  ['22', 'GB', 'People & Blogs'],
#  ['23', 'GB', 'Comedy'],
#  ['24', 'GB', 'Entertainment'],
#  ['25', 'GB', 'News & Politics'],
#  ['26', 'GB', 'Howto & Style'],
#  ['27', 'GB', 'Education'],
#  ['28', 'GB', 'Science & Technology'],
#  ['30', 'GB', 'Movies'],
#  ['31', 'GB', 'Anime/Animation'],
#  ['32', 'GB', 'Action/Adventure'],
#  ['33', 'GB', 'Classics'],
#  ['34', 'GB', 'Comedy'],
#  ['35', 'GB', 'Documentary'],
#  ['36', 'GB', 'Drama'],
#  ['37', 'GB', 'Family'],
#  ['38', 'GB', 'Foreign'],
#  ['39', 'GB', 'Horror'],
#  ['40', 'GB', 'Sci-Fi/Fantasy'],
#  ['41', 'GB', 'Thriller'],
#  ['42', 'GB', 'Shorts'],
#  ['43', 'GB', 'Shows'],
#  ['44', 'GB', 'Trailers'],
#  ['1', 'CA', 'Film & Animation'],
#  ['2', 'CA', 'Autos & Vehicles'],
#  ['1', 'CA', 'Music'],
#  ['1', 'CA', 'Pets & Animals'],
#  ['1', 'CA', 'Sports'],
#  ['1', 'CA', 'Short Movies'],
#  ['1', 'CA', 'Travel & Events'],
#  ['2', 'CA', 'Gaming'],
#  ['2', 'CA', 'Videoblogging'],
#  ['2', 'CA', 'People & Blogs'],
#  ['2', 'CA', 'Comedy'],
#  ['2', 'CA', 'Entertainment'],
#  ['2', 'CA', 'News & Politics'],
#  ['2', 'CA', 'Howto & Style'],
#  ['2', 'CA', 'Education'],
#  ['2', 'CA', 'Science & Technology'],
#  ['3', 'CA', 'Movies'],
#  ['3', 'CA', 'Anime/Animation'],
#  ['3', 'CA', 'Action/Adventure'],
#  ['3', 'CA', 'Classics'],
#  ['3', 'CA', 'Comedy'],
#  ['3', 'CA', 'Documentary'],
#  ['3', 'CA', 'Drama'],
#  ['3', 'CA', 'Family'],
#  ['3', 'CA', 'Foreign'],
#  ['3', 'CA', 'Horror'],
#  ['4', 'CA', 'Sci-Fi/Fantasy'],
#  ['4', 'CA', 'Thriller'],
#  ['4', 'CA', 'Shorts'],
#  ['4', 'CA', 'Shows'],
#  ['4', 'CA', 'Trailers'],
#  ['1', 'US', 'Film & Animation'],
#  ['2', 'US', 'Autos & Vehicles'],
#  ['1', 'US', 'Music'],
#  ['1', 'US', 'Pets & Animals'],
#  ['1', 'US', 'Sports'],
#  ['1', 'US', 'Short Movies'],
#  ['1', 'US', 'Travel & Events'],
#  ['2', 'US', 'Gaming'],
#  ['2', 'US', 'Videoblogging'],
#  ['2', 'US', 'People & Blogs'],
#  ['2', 'US', 'Comedy'],
#  ['2', 'US', 'Entertainment'],
#  ['2', 'US', 'News & Politics'],
#  ['2', 'US', 'Howto & Style'],
#  ['2', 'US', 'Education'],
#  ['2', 'US', 'Science & Technology'],
#  ['2', 'US', 'Nonprofits & Activism'],
#  ['3', 'US', 'Movies'],
#  ['3', 'US', 'Anime/Animation'],
#  ['3', 'US', 'Action/Adventure'],
#  ['3', 'US', 'Classics'],
#  ['3', 'US', 'Comedy'],
#  ['3', 'US', 'Documentary'],
#  ['3', 'US', 'Drama'],
#  ['3', 'US', 'Family'],
#  ['3', 'US', 'Foreign'],
#  ['3', 'US', 'Horror'],
#  ['4', 'US', 'Sci-Fi/Fantasy'],
#  ['4', 'US', 'Thriller'],
#  ['4', 'US', 'Shorts'],
#  ['4', 'US', 'Shows'],
#  ['4', 'US', 'Trailers'],
#  ['1', 'GB', 'Film & Animation'],
#  ['2', 'GB', 'Autos & Vehicles'],
#  ['1', 'GB', 'Music'],
#  ['1', 'GB', 'Pets & Animals'],
#  ['1', 'GB', 'Sports'],
#  ['1', 'GB', 'Short Movies'],
#  ['1', 'GB', 'Travel & Events'],
#  ['2', 'GB', 'Gaming'],
#  ['2', 'GB', 'Videoblogging'],
#  ['2', 'GB', 'People & Blogs'],
#  ['2', 'GB', 'Comedy'],
#  ['2', 'GB', 'Entertainment'],
#  ['2', 'GB', 'News & Politics'],
#  ['2', 'GB', 'Howto & Style'],
#  ['2', 'GB', 'Education'],
#  ['2', 'GB', 'Science & Technology'],
#  ['3', 'GB', 'Movies'],
#  ['3', 'GB', 'Anime/Animation'],
#  ['3', 'GB', 'Action/Adventure'],
#  ['3', 'GB', 'Classics'],
#  ['3', 'GB', 'Comedy'],
#  ['3', 'GB', 'Documentary'],
#  ['3', 'GB', 'Drama'],
#  ['3', 'GB', 'Family'],
#  ['3', 'GB', 'Foreign'],
#  ['3', 'GB', 'Horror'],
#  ['4', 'GB', 'Sci-Fi/Fantasy'],
#  ['4', 'GB', 'Thriller'],
#  ['4', 'GB', 'Shorts'],
#  ['4', 'GB', 'Shows'],
#  ['4', 'GB', 'Trailers'],
#  ['1', 'CA', 'Film & Animation'],
#  ['2', 'CA', 'Autos & Vehicles'],
#  ['10', 'CA', 'Music'],
#  ['15', 'CA', 'Pets & Animals'],
#  ['17', 'CA', 'Sports'],
#  ['18', 'CA', 'Short Movies'],
#  ['19', 'CA', 'Travel & Events'],
#  ['20', 'CA', 'Gaming'],
#  ['21', 'CA', 'Videoblogging'],
#  ['22', 'CA', 'People & Blogs'],
#  ['23', 'CA', 'Comedy'],
#  ['24', 'CA', 'Entertainment'],
#  ['25', 'CA', 'News & Politics'],
#  ['26', 'CA', 'Howto & Style'],
#  ['27', 'CA', 'Education'],
#  ['28', 'CA', 'Science & Technology'],
#  ['30', 'CA', 'Movies'],
#  ['31', 'CA', 'Anime/Animation'],
#  ['32', 'CA', 'Action/Adventure'],
#  ['33', 'CA', 'Classics'],
#  ['34', 'CA', 'Comedy'],
#  ['35', 'CA', 'Documentary'],
#  ['36', 'CA', 'Drama'],
#  ['37', 'CA', 'Family'],
#  ['38', 'CA', 'Foreign'],
#  ['39', 'CA', 'Horror'],
#  ['40', 'CA', 'Sci-Fi/Fantasy'],
#  ['41', 'CA', 'Thriller'],
#  ['42', 'CA', 'Shorts'],
#  ['43', 'CA', 'Shows'],
#  ['44', 'CA', 'Trailers'],
#  ['1', 'US', 'Film & Animation'],
#  ['2', 'US', 'Autos & Vehicles'],
#  ['10', 'US', 'Music'],
#  ['15', 'US', 'Pets & Animals'],
#  ['17', 'US', 'Sports'],
#  ['18', 'US', 'Short Movies'],
#  ['19', 'US', 'Travel & Events'],
#  ['20', 'US', 'Gaming'],
#  ['21', 'US', 'Videoblogging'],
#  ['22', 'US', 'People & Blogs'],
#  ['23', 'US', 'Comedy'],
#  ['24', 'US', 'Entertainment'],
#  ['25', 'US', 'News & Politics'],
#  ['26', 'US', 'Howto & Style'],
#  ['27', 'US', 'Education'],
#  ['28', 'US', 'Science & Technology'],
#  ['29', 'US', 'Nonprofits & Activism'],
#  ['30', 'US', 'Movies'],
#  ['31', 'US', 'Anime/Animation'],
#  ['32', 'US', 'Action/Adventure'],
#  ['33', 'US', 'Classics'],
#  ['34', 'US', 'Comedy'],
#  ['35', 'US', 'Documentary'],
#  ['36', 'US', 'Drama'],
#  ['37', 'US', 'Family'],
#  ['38', 'US', 'Foreign'],
#  ['39', 'US', 'Horror'],
#  ['40', 'US', 'Sci-Fi/Fantasy'],
#  ['41', 'US', 'Thriller'],
#  ['42', 'US', 'Shorts'],
#  ['43', 'US', 'Shows'],
#  ['44', 'US', 'Trailers'],
#  ['1', 'GB', 'Film & Animation'],
#  ['2', 'GB', 'Autos & Vehicles'],
#  ['10', 'GB', 'Music'],
#  ['15', 'GB', 'Pets & Animals'],
#  ['17', 'GB', 'Sports'],
#  ['18', 'GB', 'Short Movies'],
#  ['19', 'GB', 'Travel & Events'],
#  ['20', 'GB', 'Gaming'],
#  ['21', 'GB', 'Videoblogging'],
#  ['22', 'GB', 'People & Blogs'],
#  ['23', 'GB', 'Comedy'],
#  ['24', 'GB', 'Entertainment'],
#  ['25', 'GB', 'News & Politics'],
#  ['26', 'GB', 'Howto & Style'],
#  ['27', 'GB', 'Education'],
#  ['28', 'GB', 'Science & Technology'],
#  ['30', 'GB', 'Movies'],
#  ['31', 'GB', 'Anime/Animation'],
#  ['32', 'GB', 'Action/Adventure'],
#  ['33', 'GB', 'Classics'],
#  ['34', 'GB', 'Comedy'],
#  ['35', 'GB', 'Documentary'],
#  ['36', 'GB', 'Drama'],
#  ['37', 'GB', 'Family'],
#  ['38', 'GB', 'Foreign'],
#  ['39', 'GB', 'Horror'],
#  ['40', 'GB', 'Sci-Fi/Fantasy'],
#  ['41', 'GB', 'Thriller'],
#  ['42', 'GB', 'Shorts'],
#  ['43', 'GB', 'Shows'],
#  ['44', 'GB', 'Trailers']]
