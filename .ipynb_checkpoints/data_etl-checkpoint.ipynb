# %%
import pandas as pd
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()

# %% [markdown]
# ### Store CSV into DataFrame

# %%
csv_fileCA = "resources/CAvideos.csv"
cavideos_df = pd.read_csv(csv_fileCA)
cavideos_df.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           23  2017-11-13T17:00:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# ...

# %% [markdown]
# ### Create new data with select columns

# %%
new_cavideos_df = cavideos_df[['video_id', 'trending_date', 'title','channel_title', 'category_id', 'publish_time', 'views', 'likes','dislikes', 'comment_count'  ]].copy()
new_cavideos_df.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time     views    likes  dislikes  \
# 0           10  2017-11-10T17:00:03.000Z  17158579   787425     43420
# 1           23  2017-11-13T17:00:00.000Z   1014651   127794      1688
# 2           23  2017-11-12T19:05:24.000Z   3191434   146035      5339
# 3           24  2017-11-12T18:01:41.000Z   2095828   132239      1989
# ...

# %%
new_cavideos_df.insert(1,'country','CA')
new_cavideos_df
#new_cavideos_df=new_cavideos_df.drop(['country'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-476e480635f9> in <module>()
# ----> 1 new_cavideos_df.insert(1,'country','CA')
#       2 new_cavideos_df
#       3 #new_cavideos_df=new_cavideos_df.drop(['country'], axis=1)
#
# AttributeError: 'NoneType' object has no attribute 'insert'

# %%
new_cavideos_df

# %%
new_cavideos_df.to_csv('output_data/ca.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-575c52d50f15> in <module>()
# ----> 1 new_cavideos_df.to_csv('output_data/ca.csv')
#
# AttributeError: 'NoneType' object has no attribute 'to_csv'

# %%
csv_fileUS = "resources/USvideos.csv"
usvideos_df = pd.read_csv(csv_fileUS)
usvideos_df.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
new_usvideos_df = usvideos_df[['video_id', 'trending_date', 'title','channel_title', 'category_id', 'publish_time', 'views', 'likes','dislikes', 'comment_count'  ]].copy()

new_usvideos_df
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      1ZAPwfrtAFY      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      puqaWrEC7tY      17.14.11
# 4      d380meD0W0M      17.14.11
# 5      gHZ1Qz0KiKM      17.14.11
# 6      39idVpFF7NQ      17.14.11
# 7      nc99ccSXST0      17.14.11
# 8      jr9QtXwC9vc      17.14.11
# 9      TUmyygCMMGA      17.14.11
# 10     9wRQljFNDW8      17.14.11
# 11     VifQlJit6A0      17.14.11
# 12     5E4ZBSInqUU      17.14.11
# 13     GgVmn66oK_A      17.14.11
# 14     TaTleo4cOs8      17.14.11
# 15     kgaO45SyaO4      17.14.11
# 16     ZAQs-ctOqXQ      17.14.11
# 17     YVfyYrEmzgM      17.14.11
# 18     eNSN6qet1kE      17.14.11
# 19     B5HORANmzHw      17.14.11
# 20     vU14JY3x81A      17.14.11
# 21     6VhU_T463sU      17.14.11
# 22     _-aDHxoblr4      17.14.11
# 23     JBZTZZAcFTw      17.14.11
# 24     lZ68j2J_GOM      17.14.11
# 25     dRpNZV18N_g      17.14.11
# 26     fcVjitaM3LY      17.14.11
# ...

# %%
new_usvideos_df.insert(1,'country','US')
#new_usvideos_df = new_usvideos_df.drop(['country'], axis=1)

# %%
new_usvideos_df
# Out:
#           video_id country trending_date  \
# 0      2kyS6SvSYSE      US      17.14.11
# 1      1ZAPwfrtAFY      US      17.14.11
# 2      5qpjK5DgCt4      US      17.14.11
# 3      puqaWrEC7tY      US      17.14.11
# 4      d380meD0W0M      US      17.14.11
# 5      gHZ1Qz0KiKM      US      17.14.11
# 6      39idVpFF7NQ      US      17.14.11
# 7      nc99ccSXST0      US      17.14.11
# 8      jr9QtXwC9vc      US      17.14.11
# 9      TUmyygCMMGA      US      17.14.11
# 10     9wRQljFNDW8      US      17.14.11
# 11     VifQlJit6A0      US      17.14.11
# 12     5E4ZBSInqUU      US      17.14.11
# 13     GgVmn66oK_A      US      17.14.11
# 14     TaTleo4cOs8      US      17.14.11
# 15     kgaO45SyaO4      US      17.14.11
# 16     ZAQs-ctOqXQ      US      17.14.11
# 17     YVfyYrEmzgM      US      17.14.11
# 18     eNSN6qet1kE      US      17.14.11
# 19     B5HORANmzHw      US      17.14.11
# 20     vU14JY3x81A      US      17.14.11
# 21     6VhU_T463sU      US      17.14.11
# ...

# %%
new_usvideos_df.to_csv('output_data/us.csv')

# %%
csv_fileGB = "resources/GBvideos.csv"
gbvideos_df = pd.read_csv(csv_fileGB)
gbvideos_df.tail()
# Out:
#           video_id trending_date  \
# 38911  l884wKofd54      18.14.06
# 38912  IP8k2xkhOdI      18.14.06
# 38913  Il-an3K9pjg      18.14.06
# 38914  -DRsfNObKIQ      18.14.06
# 38915  4YFo4bdMO8Q      18.14.06
#
#                                                    title  \
# 38911  Enrique Iglesias - MOVE TO MIAMI (Official Vid...
# 38912  Jacob Sartorius - Up With It (Official Music V...
# 38913                 Anne-Marie - 2002 [Official Video]
# 38914  Eleni Foureira - Fuego - Cyprus - LIVE - First...
# 38915  KYLE - Ikuyo feat.  2 Chainz & Sophia Black [A...
#
#                  channel_title  category_id              publish_time  \
# 38911      EnriqueIglesiasVEVO           10  2018-05-09T07:00:01.000Z
# 38912          Jacob Sartorius           10  2018-05-11T17:09:16.000Z
# 38913               Anne-Marie           10  2018-05-08T11:05:08.000Z
# 38914  Eurovision Song Contest           24  2018-05-08T20:32:32.000Z
# ...

# %%
new_gbvideos_df = gbvideos_df[['video_id', 'trending_date', 'title','channel_title', 'category_id', 'publish_time', 'views', 'likes','dislikes', 'comment_count'  ]].copy()
new_gbvideos_df.head()
# Out:
#       video_id trending_date  \
# 0  Jw1Y-zhQURU      17.14.11
# 1  3s1rvMFUweQ      17.14.11
# 2  n1WpP7iowLc      17.14.11
# 3  PUTEiSjKwJU      17.14.11
# 4  rHwDegptbI4      17.14.11
#
#                                                title  \
# 0      John Lewis Christmas Ad 2017 - #MozTheMonster
# 1          Taylor Swift: …Ready for It? (Live) - SNL
# 2         Eminem - Walk On Water (Audio) ft. Beyoncé
# 3  Goals from Salford City vs Class of 92 and Fri...
# 4  Dashcam captures truck's near miss with child ...
#
#                 channel_title  category_id              publish_time  \
# 0                  John Lewis           26  2017-11-10T07:38:29.000Z
# 1         Saturday Night Live           24  2017-11-12T06:24:44.000Z
# 2                  EminemVEVO           10  2017-11-10T17:00:03.000Z
# 3  Salford City Football Club           17  2017-11-13T02:30:38.000Z
# 4            Cute Girl Videos           25  2017-11-13T01:45:13.000Z
#
# ...

# %%
new_gbvideos_df.insert(1,'country','GB')

# %%
new_gbvideos_df
# Out:
#           video_id country trending_date  \
# 0      Jw1Y-zhQURU      GB      17.14.11
# 1      3s1rvMFUweQ      GB      17.14.11
# 2      n1WpP7iowLc      GB      17.14.11
# 3      PUTEiSjKwJU      GB      17.14.11
# 4      rHwDegptbI4      GB      17.14.11
# 5      AumaWl0TNBo      GB      17.14.11
# 6      2Vv-BfVoq4g      GB      17.14.11
# 7      -N5eucPMTTc      GB      17.14.11
# 8      LMCuKltaY3M      GB      17.14.11
# 9      9t9u_yPEidY      GB      17.14.11
# 10     ONQ-fAp5X64      GB      17.14.11
# 11     Dlwf5u2BLAg      GB      17.14.11
# 12     NVCqz2BDfcQ      GB      17.14.11
# 13     MyEqfBkzESU      GB      17.14.11
# 14     b4vTZx_AtHk      GB      17.14.11
# 15     BsfhHKx6ajA      GB      17.14.11
# 16     DIU3xPdhCBI      GB      17.14.11
# 17     pz95u3UVpaM      GB      17.14.11
# 18     jp9hK-jY6yY      GB      17.14.11
# 19     gEHCXl4J9Qo      GB      17.14.11
# 20     OWvCCu2t6Ts      GB      17.14.11
# 21     6p-QzY5bxJ0      GB      17.14.11
# ...

# %%
new_gbvideos_df.to_csv('output_data/gb.csv')

# %%
final_df=pd.concat([new_cavideos_df,new_usvideos_df,new_gbvideos_df])
final_df
# Out:
#           video_id country trending_date  \
# 0      n1WpP7iowLc      CA      17.14.11
# 1      0dBIkQ4Mz1M      CA      17.14.11
# 2      5qpjK5DgCt4      CA      17.14.11
# 3      d380meD0W0M      CA      17.14.11
# 4      2Vv-BfVoq4g      CA      17.14.11
# 5      0yIWz1XEeyc      CA      17.14.11
# 6      _uM5kFfkhB8      CA      17.14.11
# 7      2kyS6SvSYSE      CA      17.14.11
# 8      JzCsM1vtn78      CA      17.14.11
# 9      43sm-QwLcx4      CA      17.14.11
# 10     H1KBHFXm2Bg      CA      17.14.11
# 11     U3xLOo-CNwo      CA      17.14.11
# 12     FyZMnhUtLfE      CA      17.14.11
# 13     7MxiQ4v0EnE      CA      17.14.11
# 14     LUzsOyWp9lw      CA      17.14.11
# 15     AS9-ITLhQxo      CA      17.14.11
# 16     gifPYwArCVQ      CA      17.14.11
# 17     8NHA23f7LvU      CA      17.14.11
# 18     fy-CuCzaPp8      CA      17.14.11
# 19     kzwfHumJyYc      CA      17.14.11
# 20     nc99ccSXST0      CA      17.14.11
# 21     puqaWrEC7tY      CA      17.14.11
# ...

# %%
csv_fileF = "output_data/final.csv"
final_df = pd.read_csv(csv_fileF)
final_df
# Out:
#         Unnamed: 0     video_id country trending_date  \
# 0                0  n1WpP7iowLc      CA      17.14.11
# 1                1  0dBIkQ4Mz1M      CA      17.14.11
# 2                2  5qpjK5DgCt4      CA      17.14.11
# 3                3  d380meD0W0M      CA      17.14.11
# 4                4  2Vv-BfVoq4g      CA      17.14.11
# 5                5  0yIWz1XEeyc      CA      17.14.11
# 6                6  _uM5kFfkhB8      CA      17.14.11
# 7                7  2kyS6SvSYSE      CA      17.14.11
# 8                8  JzCsM1vtn78      CA      17.14.11
# 9                9  43sm-QwLcx4      CA      17.14.11
# 10              10  H1KBHFXm2Bg      CA      17.14.11
# 11              11  U3xLOo-CNwo      CA      17.14.11
# 12              12  FyZMnhUtLfE      CA      17.14.11
# 13              13  7MxiQ4v0EnE      CA      17.14.11
# 14              14  LUzsOyWp9lw      CA      17.14.11
# 15              15  AS9-ITLhQxo      CA      17.14.11
# ...

# %%
new_final_df = final_df[['video_id','country', 'trending_date', 'title','channel_title', 'category_id', 'publish_time', 'views', 'likes','dislikes', 'comment_count'  ]].copy()
new_final_df
# Out:
#            video_id country trending_date  \
# 0       n1WpP7iowLc      CA      17.14.11
# 1       0dBIkQ4Mz1M      CA      17.14.11
# 2       5qpjK5DgCt4      CA      17.14.11
# 3       d380meD0W0M      CA      17.14.11
# 4       2Vv-BfVoq4g      CA      17.14.11
# 5       0yIWz1XEeyc      CA      17.14.11
# 6       _uM5kFfkhB8      CA      17.14.11
# 7       2kyS6SvSYSE      CA      17.14.11
# 8       JzCsM1vtn78      CA      17.14.11
# 9       43sm-QwLcx4      CA      17.14.11
# 10      H1KBHFXm2Bg      CA      17.14.11
# 11      U3xLOo-CNwo      CA      17.14.11
# 12      FyZMnhUtLfE      CA      17.14.11
# 13      7MxiQ4v0EnE      CA      17.14.11
# 14      LUzsOyWp9lw      CA      17.14.11
# 15      AS9-ITLhQxo      CA      17.14.11
# 16      gifPYwArCVQ      CA      17.14.11
# 17      8NHA23f7LvU      CA      17.14.11
# 18      fy-CuCzaPp8      CA      17.14.11
# 19      kzwfHumJyYc      CA      17.14.11
# 20      nc99ccSXST0      CA      17.14.11
# ...

# %%
#new_final_df.insert(0,'ID',range(1,1+len(new_final_df)))
#new_final_df=new_final_df.set_index('ID')
new_final_df
# Out:
#            video_id country trending_date  \
# ID
# 1       n1WpP7iowLc      CA      17.14.11
# 2       0dBIkQ4Mz1M      CA      17.14.11
# 3       5qpjK5DgCt4      CA      17.14.11
# 4       d380meD0W0M      CA      17.14.11
# 5       2Vv-BfVoq4g      CA      17.14.11
# 6       0yIWz1XEeyc      CA      17.14.11
# 7       _uM5kFfkhB8      CA      17.14.11
# 8       2kyS6SvSYSE      CA      17.14.11
# 9       JzCsM1vtn78      CA      17.14.11
# 10      43sm-QwLcx4      CA      17.14.11
# 11      H1KBHFXm2Bg      CA      17.14.11
# 12      U3xLOo-CNwo      CA      17.14.11
# 13      FyZMnhUtLfE      CA      17.14.11
# 14      7MxiQ4v0EnE      CA      17.14.11
# 15      LUzsOyWp9lw      CA      17.14.11
# 16      AS9-ITLhQxo      CA      17.14.11
# 17      gifPYwArCVQ      CA      17.14.11
# 18      8NHA23f7LvU      CA      17.14.11
# 19      fy-CuCzaPp8      CA      17.14.11
# 20      kzwfHumJyYc      CA      17.14.11
# 21      nc99ccSXST0      CA      17.14.11
# ...

# %%
new_final_df.to_csv('output_data/final.csv')

# %% [markdown]
# ### Store JSON data into a DataFrame

# %%
# Out:
# "resources/CA_category_id.json"

# %% [markdown]
# ### Clean DataFrame

# %%
new_customer_location_df = customer_location_df[["id", "address", "us_state"]].copy()
new_customer_location_df.head()
# Out:
#    id                address  us_state
# 0   1  043 Mockingbird Place   Indiana
# 1   2       4 Prentice Point   Indiana
# 2   3      46 Derek Junction     Texas
# 3   4  11966 Old Shore Place  Missouri
# 4   5     5 Evergreen Circle  New York

# %% [markdown]
# ### Connect to local database

# %%
rds_connection_string = "root:root123@127.0.0.1:3306/customer_db"
engine = create_engine(f'mysql://{rds_connection_string}')

# %% [markdown]
# ### Check for tables

# %%
engine.table_names()
# Out:
# ['customer_location', 'customer_name']

# %% [markdown]
# ### Use pandas to load csv converted DataFrame into database

# %%
new_customer_data_df.to_sql(name='customer_name', con=engine, if_exists='append', index=False)

# %% [markdown]
# ### Use pandas to load json converted DataFrame into database

# %%
new_customer_location_df.to_sql(name='customer_location', con=engine, if_exists='append', index=False)

# %% [markdown]
# ### Confirm data has been added by querying the customer_name table
# * NOTE: can also check using pgAdmin

# %%
pd.read_sql_query('select * from customer_name', con=engine).head()
# Out:
#    id first_name last_name
# 0   1    Benetta   Cancott
# 1   2     Lilyan    Cherry
# 2   3    Ezekiel   Benasik
# 3   4    Kennedy     Atlay
# 4   5    Sanford    Salmen

# %% [markdown]
# ### Confirm data has been added by querying the customer_location table

# %%
pd.read_sql_query('select * from customer_location', con=engine).head()
# Out:
#    id                address  us_state
# 0   1  043 Mockingbird Place   Indiana
# 1   2       4 Prentice Point   Indiana
# 2   3      46 Derek Junction     Texas
# 3   4  11966 Old Shore Place  Missouri
# 4   5     5 Evergreen Circle  New York
